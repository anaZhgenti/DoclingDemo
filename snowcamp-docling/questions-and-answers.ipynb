# %% [markdown]
# # LangChain Demo: Raw PDF vs Markdown
# This notebook demonstrates why raw PDFs perform poorly with LLMs by comparing:
# 1. **Raw PDF**: Basic PyPDF2 extraction with no preprocessing
# 2. **Markdown**: Proper preprocessing with chunking, embeddings, and RAG
#
# The goal is to show that proper document formatting is essential for good LLM performance.

# %%
# Automatically reload modules when they change
# This ensures changes to QandAFunctions.py are picked up automatically
# %load_ext autoreload
# %autoreload 2

# %%
from QandAFunctions import initialize_environment

# Load environment variables from config.env
initialize_environment()
# Out:
# ✓ Environment initialized: OPENAI_API_KEY loaded

# %%
from pathlib import Path
from langchain_core.prompts import PromptTemplate

# Setup main variables
PDF_PATH = 'report.pdf'
MARKDOWN_PATH = Path("result") / "report.md"
QUESTION = "In 2021, what is the impact of electric trains on the green bond asset portfolio, in millions of euros?"

# %% [markdown]
# ## Set up PDF Reading (No Preprocessing)

# %%
from QandAFunctions import load_pdf

# Load PDF and setup processing chain
pdf_content = load_pdf(PDF_PATH)

# %% [markdown]
# ## Questions for the PDF

# %%
from QandAFunctions import ask_pdf

print(f"\n{'='*80}")
print(f"QUESTION : {QUESTION}")
print('='*80)

pdf_response = ask_pdf(pdf_content, QUESTION)

print(f"\nPDF ANSWER (NO PREPROCESSING):")
if "error" in pdf_response:
    print(f"{pdf_response['answer']}")
else:
    answer = pdf_response.get('answer', 'No answer')
    print(f"{answer}")
# Out:
# ================================================================================
# QUESTION : In 2021, what is the impact of electric trains on the green bond asset portfolio, in millions of euros?
# ================================================================================
#
# PDF ANSWER (NO PREPROCESSING):
# Chunk 1: Based on the provided content, there is no information regarding the impact of electric trains on the green bond asset portfolio in millions of euros in 2021. The content focuses on the Climate Financial Risk Forum Guide 2023 and the Data, Disclosures, and Metrics Working Group.
#
# Chunk 2: The impact of electric trains on the green bond asset portfolio in millions of euros is not mentioned in the provided content.
#
# Chunk 3: Based on the provided content, there is no specific information or mention about the impact of electric trains on the green bond asset portfolio in millions of euros in 2021. Therefore, it is not possible to determine the impact of electric trains on the green bond asset portfolio from the given content.
#
# Chunk 4: Based on the provided content, there is no specific information about the impact of electric trains on the green bond asset portfolio in millions of euros in 2021. The content primarily focuses on climate-related financial risks, disclosure requirements for asset managers, banks, and insurers, and real-world examples of metrics and reports related to transition risks.
#
# Chunk 5: There is no information provided in the content about the impact of electric trains on the green bond asset portfolio in millions of euros in 2021.
#
# Chunk 6: Based on the provided content, there is no information about the impact of electric trains on the green bond asset portfolio in millions of euros in 2021. The content primarily focuses on climate-related financial disclosures, financed emissions, and portfolio alignment metrics of financial institutions.
#
# Chunk 7: Based on the provided content, there is no specific information about the impact of electric trains on the green bond asset portfolio in millions of euros in 2021. The content primarily discusses various metrics, disclosures, and real-world examples related to climate financial risk and transition finance.
#
# Chunk 8: The impact of electric trains on the green bond asset portfolio in millions of euros is not specified in the provided content.
#
# Chunk 9: Based on the provided content, there is no specific mention of the impact of electric trains on the green bond asset portfolio in millions of euros in 2021. Therefore, it is not possible to provide an answer to this question based on the given content.

# %% [markdown]
# ## Set up Markdown File Reading

# %%
from QandAFunctions import load_markdown

# Load markdown and setup RAG chain
# md_rag_chain, md_splits = load_and_setup_markdown_rag(MARKDOWN_PATH)
md_content = load_markdown(MARKDOWN_PATH)

# %% [markdown]
# ## Questions for the Formatted Markdown

# %%
from QandAFunctions import ask_markdown

print(f"\n{'='*80}")
print(f"QUESTION : {QUESTION}")
print('='*80)

# md_response = ask_markdown(md_rag_chain, QUESTION, "Markdown")
md_response = ask_markdown(md_content, QUESTION)

print(f"\n📝 MARKDOWN ANSWER:")
if "error" in md_response:
    print(f"{md_response['answer']}")
else:
    # Display full answer without clipping (or with much larger threshold)
    answer = md_response.get('answer', 'No answer')
    print(f"{answer}")
# Out:
# ================================================================================
# QUESTION : In 2021, what is the impact of electric trains on the green bond asset portfolio, in millions of euros?
# ================================================================================
#
# 📝 MARKDOWN ANSWER:
# Chunk 1: Based on the provided content, there is no information about the impact of electric trains on the green bond asset portfolio in millions of euros in 2021. Therefore, the answer to the question is not applicable or cannot be determined from the given content.
#
# Chunk 2: Based on the provided content, there is no specific mention of the impact of electric trains on the green bond asset portfolio in millions of euros in 2021. Therefore, the answer to the question cannot be determined from the given information.
#
# Chunk 3: Based on the provided content, there is no specific mention of the impact of electric trains on the green bond asset portfolio in millions of euros in 2021. Therefore, it is not possible to provide an answer to this question based on the given information.
#
# Chunk 4: Based on the provided content, the impact of electric trains on the green bond asset portfolio in 2021 is not explicitly mentioned. The information provided focuses on transition risk and climate-related metrics of various financial institutions, but does not specifically address the impact of electric trains on green bond asset portfolios in terms of millions of euros. Therefore, the answer to the question cannot be determined from the given content.
#
# Chunk 5: In 2021, the impact of electric trains on the green bond asset portfolio is not explicitly mentioned in the provided content. Therefore, it is not possible to determine the impact in millions of euros based on the information given.
#
# Chunk 6: There is no mention of the impact of electric trains on the green bond asset portfolio in the provided content. Therefore, it is not possible to determine the impact in millions of euros based on the information provided.
#
# Chunk 7: Based on the provided content, there is no specific mention of the impact of electric trains on the green bond asset portfolio in 2021 in millions of euros. Therefore, the answer to the question is not available in the given content.
#
# Chunk 8: The impact of electric trains on the green bond asset portfolio in 2021 is not explicitly stated in the provided content. Therefore, it is not possible to determine the impact of electric trains on the green bond asset portfolio in millions of euros based on the information provided.
#
# Chunk 9: In 2021, the impact of electric trains on the green bond asset portfolio is 285 million euros.
#
# Chunk 10: The impact of electric trains on the green bond asset portfolio in millions of euros is not provided in the given content. Therefore, it is not possible to answer the question based on the provided information.
#
# Chunk 11: The impact of electric trains on the green bond asset portfolio in millions of euros is not provided in the raw content from the PDF document.
